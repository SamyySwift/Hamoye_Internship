# %% [markdown]
# <a href="https://colab.research.google.com/github/SamyySwift/Hamoye_Internship/blob/master/Homoye_DataScience_Quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -o fuel_data https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
fuel_data = pd.read_csv('/content/fuel_ferc1.csv')
fuel_data.head()
# Out:
#                 record_id  ...  fuel_cost_per_mmbtu
# 0   f1_fuel_1994_12_1_0_7  ...                1.121
# 1  f1_fuel_1994_12_1_0_10  ...                1.120
# 2   f1_fuel_1994_12_2_0_1  ...                1.650
# 3   f1_fuel_1994_12_2_0_7  ...                1.970
# 4  f1_fuel_1994_12_2_0_10  ...                2.570
#
# [5 rows x 11 columns]
